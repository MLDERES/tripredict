# %%
import pandas as pd
import requests

# %%
base_url = 'https://www.ironman.com/triathlon/events/americas/ironman-70.3/wisconsin/results.aspx#axzz65RyT87Zi'
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(base_url, headers=header)

results_df = pd.read_html(r.text)
results_df
# Out:
# [                      Name Country  Div Rank  Gender Rank  Overall Rank  \
#  0              Engel, Eric     USA         1            1             1
#  1          Redner, Patrick     USA         2            2             2
#  2            Lammers, Vant     USA         3            3             3
#  3      Leutenegger, Dustin     USA         1            4             4
#  4           Henry, Malachi     USA         1            5             5
#  5           Leigl, Anthony     USA         2            6             6
#  6           Greist, Revere     USA         1            7             7
#  7             Roby, Jordan     USA         2            8             8
#  8   Ramirez Pinho, Alfredo     PRY         4            9             9
#  9          Hidalgo, Javier     USA         1           10            10
#  10      Borowik, Sebastian     POL         2           11            11
#  11           Adriaens, Joe     USA         5           12            12
#  12        Arlandson, Dan J     USA         3           13            13
#  13              Luy, David     USA         3           14            14
#  14               Pou, Luis     PRI         4           15            15
#  15          Willing, Brian     USA         3           16            16
#  16             Iott, Scott     USA         5           17            17
#  17             Montes, R J     USA         6           18            18
#  18             Moser, Eric     USA         4           18            18
#  19         Nelson, Garrett     USA         5           20            20
#
#          Swim      Bike       Run    Finish  Points
#  0   00:27:10  02:23:12  01:18:33  04:13:00    3500
#  1   00:26:56  02:26:38  01:18:24  04:16:37    3434
#  2   00:27:54  02:24:04  01:21:36  04:17:35    3417
#  3   00:33:11  02:17:47  01:22:50  04:18:06    3500
#  4   00:28:56  02:25:17  01:19:00  04:18:12    3500
#  5   00:30:01  02:22:21  01:21:03  04:18:38    3490
#  6   00:26:52  02:14:02  01:33:15  04:20:10    3500
#  7   00:30:43  02:23:23  01:21:53  04:20:17    3462
#  8   00:32:42  02:18:42  01:24:50  04:20:42    3361
#  9   00:33:23  02:21:40  01:23:19  04:23:03    3500
#  10  00:34:54  02:17:50  01:28:51  04:27:07    3426
#  11  00:28:36  02:27:43  01:26:07  04:27:25    3240
#  12  00:28:42  02:24:15  01:29:00  04:28:09    3408
#  13  00:35:54  02:24:53  01:22:14  04:28:15    3319
#  14  00:32:10  02:25:18  01:25:39  04:28:18    3405
#  15  00:31:56  02:25:59  01:26:23  04:29:09    3301
#  16  00:30:40  02:26:29  01:27:27  04:29:37    3381
#  17  00:33:08  02:28:16  01:23:50  04:29:56    3376
#  18  00:27:59  02:29:10  01:28:16  04:29:56    3288
#  19  00:31:32  02:29:54  01:24:26  04:30:16    3282  ]

# %%
user_url = 'https://www.ironman.com/triathlon/events/americas/ironman-70.3/wisconsin/results.aspx?rd=20190609&race=wisconsin70.3&bidid=42&detail=1'

# %%
r = requests.get(user_url, headers=header)

results_df = pd.read_html(r.text)
len(results_df)
# Out:
# 6

# %%
detailed_ds = pd.DataFrame()
results_df
# Out:
# [  General Info Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
#  0          BIB         42        NaN        NaN         NaN         NaN
#  1     Division      30-34        NaN        NaN         NaN         NaN
#  2          Age         31        NaN        NaN         NaN         NaN
#  3        State         WI        NaN        NaN         NaN         NaN
#  4      Country        USA        NaN        NaN         NaN         NaN
#  5   Profession        ---        NaN        NaN         NaN         NaN
#  6       Points       3500        NaN        NaN         NaN         NaN
#  7        Total     1.2 mi   00:27:10   00:27:10  01:24/100m         2.0
#
#     Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 14  \
#  0         NaN         NaN        NaN        NaN     ...             NaN
#  1         NaN         NaN        NaN        NaN     ...             NaN
#  2         NaN         NaN        NaN        NaN     ...             NaN
#  3         NaN         NaN        NaN        NaN     ...             NaN
#  4         NaN         NaN        NaN        NaN     ...             NaN
#  5         NaN         NaN        NaN        NaN     ...             NaN
#  6         NaN         NaN        NaN        NaN     ...             NaN
#  7        10.0        14.0      Total      56 mi     ...             2.0
#
#    Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19 Unnamed: 20  \
#  0         NaN         NaN          NaN          NaN          NaN         NaN
#  1         NaN         NaN          NaN          NaN          NaN         NaN
#  2         NaN         NaN          NaN          NaN          NaN         NaN
#  3         NaN         NaN          NaN          NaN          NaN         NaN
#  4         NaN         NaN          NaN          NaN          NaN         NaN
#  5         NaN         NaN          NaN          NaN          NaN         NaN
#  6         NaN         NaN          NaN          NaN          NaN         NaN
#  7         2.0       Total      13.1 mi     01:18:33     04:13:00    05:59/mi
#
#    Unnamed: 21 Unnamed: 22 Unnamed: 23
#  0         NaN         NaN         NaN
#  1         NaN         NaN         NaN
#  2         NaN         NaN         NaN
#  3         NaN         NaN         NaN
#  4         NaN         NaN         NaN
#  5         NaN         NaN         NaN
#  6         NaN         NaN         NaN
#  7         1.0         1.0         1.0
#
#  [8 rows x 24 columns],
#    Race Summary Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
#  0         Swim   00:27:10        NaN        NaN         NaN         NaN
#  1         Bike   02:23:12        NaN        NaN         NaN         NaN
#  2          Run   01:18:33        NaN        NaN         NaN         NaN
#  3      Overall   04:13:00        NaN        NaN         NaN         NaN
#  4        Total     1.2 mi   00:27:10   00:27:10  01:24/100m         2.0
#
#     Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 14  \
#  0         NaN         NaN        NaN        NaN     ...             NaN
#  1         NaN         NaN        NaN        NaN     ...             NaN
#  2         NaN         NaN        NaN        NaN     ...             NaN
#  3         NaN         NaN        NaN        NaN     ...             NaN
#  4        10.0        14.0      Total      56 mi     ...             2.0
#
#    Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19 Unnamed: 20  \
#  0         NaN         NaN          NaN          NaN          NaN         NaN
#  1         NaN         NaN          NaN          NaN          NaN         NaN
#  2         NaN         NaN          NaN          NaN          NaN         NaN
#  3         NaN         NaN          NaN          NaN          NaN         NaN
#  4         2.0       Total      13.1 mi     01:18:33     04:13:00    05:59/mi
#
#    Unnamed: 21 Unnamed: 22 Unnamed: 23
#  0         NaN         NaN         NaN
#  1         NaN         NaN         NaN
#  2         NaN         NaN         NaN
#  3         NaN         NaN         NaN
#  4         1.0         1.0         1.0
#
#  [5 rows x 24 columns],
#    Split Name Distance Split Time Race Time        Pace  Division Rank  \
#  0      Total   1.2 mi   00:27:10  00:27:10  01:24/100m              2
#
#     Gender Rank  Overall Rank Unnamed: 8 Unnamed: 9     ...     Unnamed: 14  \
#  0           10            14      Total      56 mi     ...               2
#
#    Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19 Unnamed: 20  \
#  0           2       Total      13.1 mi     01:18:33     04:13:00    05:59/mi
#
#    Unnamed: 21 Unnamed: 22 Unnamed: 23
#  0           1           1           1
#
#  [1 rows x 24 columns],
#    Split Name Distance Split Time Race Time        Pace  Division Rank  \
#  0      Total   1.2 mi   00:27:10  00:27:10  01:24/100m              2
#
#     Gender Rank  Overall Rank Unnamed: 8 Unnamed: 9     ...     Unnamed: 14  \
#  0           10            14      Total      56 mi     ...               2
#
#    Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19 Unnamed: 20  \
#  0           2       Total      13.1 mi     01:18:33     04:13:00    05:59/mi
#
#    Unnamed: 21 Unnamed: 22 Unnamed: 23
#  0           1           1           1
#
#  [1 rows x 24 columns],
#    Split Name Distance Split Time Race Time        Pace  Division Rank  \
#  0      Total   1.2 mi   00:27:10  00:27:10  01:24/100m              2
#
#     Gender Rank  Overall Rank Unnamed: 8 Unnamed: 9     ...     Unnamed: 14  \
#  0           10            14      Total      56 mi     ...               2
#
#    Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19 Unnamed: 20  \
#  0           2       Total      13.1 mi     01:18:33     04:13:00    05:59/mi
#
#    Unnamed: 21 Unnamed: 22 Unnamed: 23
#  0           1           1           1
#
#  [1 rows x 24 columns],
#                   0         1         2         3           4    5     6   \
#  0  T1: Swim-to-bike  00:02:25       NaN       NaN         NaN  NaN   NaN
#  1   T2: Bike-to-run  00:01:40       NaN       NaN         NaN  NaN   NaN
#  2             Total    1.2 mi  00:27:10  00:27:10  01:24/100m  2.0  10.0
#
#       7      8      9  ...    14   15     16       17        18        19  \
#  0   NaN    NaN    NaN ...   NaN  NaN    NaN      NaN       NaN       NaN
#  1   NaN    NaN    NaN ...   NaN  NaN    NaN      NaN       NaN       NaN
#  2  14.0  Total  56 mi ...   2.0  2.0  Total  13.1 mi  01:18:33  04:13:00
#
#           20   21   22   23
#  0       NaN  NaN  NaN  NaN
#  1       NaN  NaN  NaN  NaN
#  2  05:59/mi  1.0  1.0  1.0
#
#  [3 rows x 24 columns]]

# %%
import re
def convert_to_seconds(time):
    hours, minutes, secs = time.split(':')
    return int(hours)*3600 + int(minutes)*60 + int(secs)
    
    
class athlete:
    
    full_name = ""
    swim_time = None
    bike_time = None
    age_group = None
    run_time = None
    
    def __init__(self, swim_time, bike_time, run_time):
            self.swim_time = convert_to_seconds(swim_time)
            self.bike_time = convert_to_seconds(bike_time)
            self.run_time = convert_to_seconds(run_time)
            
    def __repl__(self):
        print(f'{}')

# %%
detailed_results = results_df[1]
rs = detailed_results[['Race Summary', 'Unnamed: 1']].set_index('Race Summary')
athlete(rs.loc['Swim'][0], rs.loc['Bike'][0], rs.loc['Run'][0])
# detailed_ds.append({'Swim':detailed_results['Race Summary']})

# %% [markdown]
# Detailed results URL
# https://www.endurance-data.com/en/results/438-ironman-italy-emilia-romagna/all/
#
# Overall list of competitions
# https://www.endurance-data.com/en/competitions/1/

# %%
from bs4 import BeautifulSoup
import re

results_urls = []
competitions_url = 'https://www.endurance-data.com/en/competitions/'

for pg in range(1,20):
    r = requests.get(f'{competitions_url}{pg}', headers=header)
    soup = BeautifulSoup(r.text)
    for race in soup.find_all('a', class_='btn'):
        href = race['href']
        if (re.search('703.*/all', href)):
            results_urls.append(href[1:])

ds = pd.Series(results_urls)
ds.to_csv('../data/results_urls.txt')
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
def

# %%
base_race_url = 'http://www.endurance-data.com/'
for race_url in ds:
    req_url = f'{base_race_url}{first}'
    r = requests.get(req_url)
    ds_results = pd.read_html(r.text,header=0)[0]
    ds_results.columns=['OverallRank''GenderRank','DivRank','Name','Bib','AgeGroup',
                              'Country',"SwimTime",'BikeTime','RunTime',
                        'Overall']
    ds_results['Race'] =
# Out:
# http://www.endurance-data.com/en/results/466-ironman-703-xiamen/all/

# %%
ds_results
# Out:
#      GenderRank  DivRank                  Name   Bib AgeGroup Country  \
# Ovr
# 1             1        1       Marten Van Riel    19     MPRO     BEL
# 2             2        2         Josh Amberger     3     MPRO     AUS
# 3             3        3              Tim Reed     2     MPRO     AUS
# 4             4        4      Kevin Collington     1     MPRO     USA
# 5             5        5  Leigh Anderson-Voigt     6     MPRO     AUS
# 6             6        6      Jakub Langhammer    11     MPRO     CZE
# 7             7        7       Thomas Springer    18     MPRO     AUT
# 8             8        8             Jens Roth    15     MPRO     DEU
# 9             9        9          Peter Jacobs     5     MPRO     AUS
# 10           10       10         Brett Johnson    10     MPRO     AUS
# 11           11        1            Tobias Chu    57   M45-49     HKG
# 12            1        1       Ashleigh Gentle    29     FPRO     AUS
# 13           12        1              Chen Wei   719   M25-29     CHN
# 14           13       11            Sam Betten     7     MPRO     AUS
# 15           14        1          Colin O'Shea  1110   M40-44     IRL
# 16           15        2         Velmar Bianco  1190   M40-44     ARG
# 17            2        2          Lesley Smith    27     FPRO     USA
# 18           16        1          Sven Weidner   793   M30-34     DEU
# 19           17        2         Andres Zimeri    84   M30-34     GTM
# 20           18        2   Golatat Kunaborimas   742   M25-29     THA
# 21           19       12       Milosz Sowinski    17     MPRO     POL
# 22            3        3       Frankie Sanjana    26     FPRO     GBR
# 23           20        3           Yanlong Kai   301   M30-34     CHN
# 24           21        2           Paul Walton  1369   M45-49     AUS
# 25           22        3           Mark Jansen    89   M45-49     AUS
# 26           23        3         Rowan Vorster    96   M40-44     ZAF
# 27           24        4        Sergey Novikov   187   M45-49     RUS
# 28           25        4                   琦 党    98   M40-44     CHN
# 29           26       13         Yu-Hung Hsieh     9     MPRO     TWN
# 30           27        5          Thomas Goetz    87   M45-49     CHE
# 31           28        1     Mathew Stephenson  1458   M50-54     GBR
# 32           29        4             Meng Yang   285   M30-34     CHN
# 33           30        1       Markus Schaefer   153   M35-39     AUS
# 34           31        5           Sven Wetzel  1207   M40-44     DEU
# 35           32        2     Kevin Tze Ho Chow  1031   M35-39     HKG
# 36            4        4         Robin Pomeroy    31     FPRO     USA
# 37           33        5         Brian Hrynkow    67   M30-34     CAN
# 38           34        1              Peng Liu   176   M18-24     CHN
# 39           35        6         Han Lin Hsieh   788   M30-34     TWN
# 40           36        3             Dandan Li   132   M35-39     CHN
# 41           37        6       Dmitrii Saiapin  1371   M45-49     RUS
# 42           38        2      Roberto De Pardi   109   M50-54     ITA
# 43           39        6       Andrew Brodziak   200   M40-44     GBR
# 44           40        7                 幸行 加藤   173   M45-49     JPN
# 45            5        5        Kate Bevilaqua    28     FPRO     AUS
# 46           41        4           Jeffrey Wei    80   M35-39     HKG
